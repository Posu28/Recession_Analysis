# %%
import pandas as pd

# %%
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
layoff = pd.read_csv('layoffs - layoffs.csv.csv')
layoff
# Out:
#                company        location        industry  total_laid_off  \
# 0     Ten Square Games         Wrocław        Consumer           120.0
# 1               Ynsect           Paris            Food            17.0
# 2               FamPay       Bengaluru         Finance             NaN
# 3                 Kumu          Manila           Media             NaN
# 4             Quadream        Tel Aviv        Security             NaN
# ...                ...             ...             ...             ...
# 2498      HopSkipDrive     Los Angeles  Transportation             8.0
# 2499       Panda Squad     SF Bay Area        Consumer             6.0
# 2500     Tamara Mellon     Los Angeles          Retail            20.0
# 2501          EasyPost  Salt Lake City       Logistics            75.0
# 2502         Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %%
layoff.columns
# Out:
# Index(['company', 'location', 'industry', 'total_laid_off',
#        'percentage_laid_off', 'date', 'stage', 'country', 'funds_raised'],
#       dtype='object')

# %%
lay_sub= layoff[['company', 'location', 'industry', 'total_laid_off',
     'date', 'stage', 'country', 'funds_raised']]

# %%
lay_sub
# Out:
#                company        location        industry  total_laid_off  \
# 0     Ten Square Games         Wrocław        Consumer           120.0
# 1               Ynsect           Paris            Food            17.0
# 2               FamPay       Bengaluru         Finance             NaN
# 3                 Kumu          Manila           Media             NaN
# 4             Quadream        Tel Aviv        Security             NaN
# ...                ...             ...             ...             ...
# 2498      HopSkipDrive     Los Angeles  Transportation             8.0
# 2499       Panda Squad     SF Bay Area        Consumer             6.0
# 2500     Tamara Mellon     Los Angeles          Retail            20.0
# 2501          EasyPost  Salt Lake City       Logistics            75.0
# 2502         Blackbaud      Charleston           Other           500.0
#
#             date     stage        country  funds_raised
# 0     2023-04-17      Seed         Poland           NaN
# ...

# %%
lay_sub.isna().sum()
# Out:
# company             0
# location            0
# industry            2
# total_laid_off    790
# date                1
# stage               6
# country             0
# funds_raised      240
# dtype: int64

# %%
lay_sub.dropna(subset=['total_laid_off'])
# Out:
#                company        location        industry  total_laid_off  \
# 0     Ten Square Games         Wrocław        Consumer           120.0
# 1               Ynsect           Paris            Food            17.0
# 5         Drip Capital     SF Bay Area         Finance            75.0
# 6     Community Gaming   New York City          Crypto            17.0
# 8                 Snyk          Boston        Security           128.0
# ...                ...             ...             ...             ...
# 2498      HopSkipDrive     Los Angeles  Transportation             8.0
# 2499       Panda Squad     SF Bay Area        Consumer             6.0
# 2500     Tamara Mellon     Los Angeles          Retail            20.0
# 2501          EasyPost  Salt Lake City       Logistics            75.0
# 2502         Blackbaud      Charleston           Other           500.0
#
#             date     stage        country  funds_raised
# 0     2023-04-17      Seed         Poland           NaN
# ...

# %%
lay_sub=lay_sub.dropna(subset=['total_laid_off'])
lay_sub
# Out:
#                company        location        industry  total_laid_off  \
# 0     Ten Square Games         Wrocław        Consumer           120.0
# 1               Ynsect           Paris            Food            17.0
# 5         Drip Capital     SF Bay Area         Finance            75.0
# 6     Community Gaming   New York City          Crypto            17.0
# 8                 Snyk          Boston        Security           128.0
# ...                ...             ...             ...             ...
# 2498      HopSkipDrive     Los Angeles  Transportation             8.0
# 2499       Panda Squad     SF Bay Area        Consumer             6.0
# 2500     Tamara Mellon     Los Angeles          Retail            20.0
# 2501          EasyPost  Salt Lake City       Logistics            75.0
# 2502         Blackbaud      Charleston           Other           500.0
#
#             date     stage        country  funds_raised
# 0     2023-04-17      Seed         Poland           NaN
# ...

# %%
lay_sub.dtypes
# Out:
# company            object
# location           object
# industry           object
# total_laid_off    float64
# date               object
# stage              object
# country            object
# funds_raised      float64
# dtype: object

# %%
lay_sub['total_laid_off'].astype('int')
lay_sub
# Out:
#                company        location        industry  total_laid_off  \
# 0     Ten Square Games         Wrocław        Consumer           120.0
# 1               Ynsect           Paris            Food            17.0
# 5         Drip Capital     SF Bay Area         Finance            75.0
# 6     Community Gaming   New York City          Crypto            17.0
# 8                 Snyk          Boston        Security           128.0
# ...                ...             ...             ...             ...
# 2498      HopSkipDrive     Los Angeles  Transportation             8.0
# 2499       Panda Squad     SF Bay Area        Consumer             6.0
# 2500     Tamara Mellon     Los Angeles          Retail            20.0
# 2501          EasyPost  Salt Lake City       Logistics            75.0
# 2502         Blackbaud      Charleston           Other           500.0
#
#             date     stage        country  funds_raised
# 0     2023-04-17      Seed         Poland           NaN
# ...

# %%
sb.countplot(x='location', data= lay_sub)
# Out:
# <Axes: xlabel='location', ylabel='count'>
